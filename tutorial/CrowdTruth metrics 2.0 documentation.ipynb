# %% [markdown]
# # CrowdTruth metrics 2.0 documentation
#
# Let:
#
# * $workers(u):$ all workers that annotate media unit $u$;
# * $units(i):$ all input media units annotated by worker $i$;
# * $WorkVec(i, u):$ annotations of worker $i$ on media unit $u$ as a binary vector;
# * $MediaUnitVec(s) = \sum_{i \in workers(s)} WorkVec(i,s)$, where $s$ is an input media unit.
#
# ## Media Unit Quality Score (UQS)
#
# The unit quality score $UQS(u)$ is computed as the average cosine similarity between all worker vectors for a given input media unit $u$, weighted by the worker quality ($WQS$) and annotation quality ($AQS$). The goal is to capture the degree of agreement in annotating the media unit. Through the weighted average, workers and annotations with lower quality will have less of an impact on the final score.
#
# $$ UQS(u) = \frac{\sum_{i, j \in workers(u)} Wcos(WorkVec(i,u), WorkVec(j,u)) \; WQS(i) \; WQS(j)}{\sum_{i, j \in workers(u)} WQS(i) \; WQS(j)}, \; i \neq j.$$
#
#
# ### Weighted Cosine
#
# To weigh the metrics with the annotation quality, we compute $Wcos$, the weighted version of the cosine similarity. This metric is only applicable to closed tasks, where annotation quality can be calculated across media units. For open-ended tasks, we consider annotation quality equal to 1 and calculate the regular cosine similarity.
#
# $$ Wcos(vec_1, vec_2) = \frac{\sum_{a} vec_1(a) \; vec_2(a) \; AQS(a)}{\sqrt{(\sum_{a} vec_1^2(a) \; AQS(a)) \; (\sum_{a} vec_2^2(a) \; AQS(a))}} .$$
#
#
# ## Worker Quality Score (WQS)
#
# The worker quality score $WQS(i)$ for a given worker $i$ is the product of 2 separate metrics - the worker-worker agreement $WWA(i)$ and the worker-media unit agreement $WUA(i)$.
#
# $$ WQS(i) = WUA(i) \; WWA(i) .$$
#
# ### Worker-Media Unit Agreement
#
# The worker-media unit agreement $WUA(i)$ is the average cosine distance between the annotations of a worker $i$ and all annotations for the media units they have worked on, weighted by the media unit and annotation quality. It calculates how much a worker disagrees with the crowd on a media unit basis. Through the weighted average, media units and anntation with lower quality will have less of an impact on the final score.
#
# $$ WSA(i) = \frac{\sum_{u \in units(i)} Wcos(WorkVec(i,u), MediaUnitVec(u) - WorkVec(i, u)) \; UQS(u)}{\sum_{u \in units(i)} UQS(u)} .$$
#
# ### Worker-Worker Agreement
#
# The worker-worker agreement $WWA(i)$ is the average cosine distance between the annotations of a worker $i$ and all other workers that have worked on the same media units as worker $i$, weighted by the worker and annotation qualities. The metric gives an indication as to whether there are consisently like-minded workers. This is useful for identifying communities of thought. Through the weighted average, workers and annotations with lower quality will have less of an impact on the final score of the given worker.
#
# $$ WWA(i) = \frac{ \sum_{j \in workers(u \in units(i))} Wcos(WorkVec(i, u), WorkVec(j, u)) \; WQS(j) \; UQS(u) }{ \sum_{j \in workers(s \in units(i))} WQS(j) \; UQS(u) }, \; i \neq j .$$
#
#
# ## Annotation Quality Score (AQS)
#
# The annotation quality score $AQS(a)$ calculates the agreement of selecting an annotation $a$, over all the media units it appears in. Therefore, it is only applicable to closed tasks, where the same annotation set is used for all input media units. It is based on $P_a(i | j)$, the probability that if a worker $j$ annotates $a$ in a media unit, worker $i$ will also annotate it.
#
# $$ P_a(i | j) = \frac{ \sum_{u \in units(i) \cap units(j) } UQS(u) \; WorkVec(i, s)(r) \; WorkVec(j, s)(r) }{ \sum_{u \in units(i) \cap units(j) } UQS(u) \; WorkVec(j, u)(r) } . $$
#
# $AQS(a)$ is the weighted average of $P_a(i | j)$ for all possible pairs of workers. Through the weighted average, input media units and workers with lower quality will have less of an impact on the final score of the annotation.
#
# $$ AQS(a) = \frac{ \sum_{i,j} WQS(i) \; WQS(j) \; P_a(i | j) }{ \sum_{i,j} WQS(i) \; WQS(j) }, i \neq j . $$
#
#
# ## Media Unit-Annotation Score (UAS)
#
# The media unit - annotation score $UAS(u, a)$ calculates the likelihood that annotation $a$ is expressed in input media unit $u$. It is the ratio of the number of workers that picked annotation $u$ over all workers that annotated the unit, weighted by the worker quality.
#
# $$ UAS(u, a) = \frac{ \sum_{i \in workers(u)} WorkVec(i,u)(a) \; WQS(i) }{ \sum_{i \in workers(u)} WQS(i) }. $$

# %% [markdown]
# # How to run the metrics

# %%
# Read data

import pandas as pd

medical_relex_filename = "relex_example.csv"
medical_relex_dataset = pd.read_csv(medical_relex_filename)

medical_relex_dataset
# Out:
#       _unit_id         _created_at         _id         _started_at  \
# 0    502540300  7/11/2014 23:53:21  1321074821  7/11/2014 23:53:03
# 1    502540300  7/12/2014 00:04:01  1321080494  7/12/2014 00:02:53
# 2    502540300  7/12/2014 00:07:10  1321082343  7/12/2014 00:06:34
# 3    502540300  7/12/2014 00:36:08  1321098346  7/12/2014 00:35:11
# 4    502540300  7/12/2014 00:51:54  1321104806  7/12/2014 00:50:47
# 5    502540300  7/12/2014 01:19:01  1321115718  7/12/2014 01:18:24
# 6    502540300  7/12/2014 01:34:31  1321122489  7/12/2014 01:34:04
# 7    502540300  7/12/2014 01:50:58  1321127102  7/12/2014 01:49:41
# 8    502540300  7/12/2014 01:58:14  1321130071  7/12/2014 01:57:04
# 9    502540300  7/12/2014 02:09:41  1321134414  7/12/2014 02:08:31
# 10   502540300  7/12/2014 03:59:08  1321176700  7/12/2014 03:58:21
# 11   502540300  7/12/2014 04:50:18  1321195542  7/12/2014 04:48:46
# 12   502540300  7/12/2014 06:17:19  1321224835  7/12/2014 06:16:19
# 13   502540300  7/12/2014 06:19:09  1321225506  7/12/2014 06:17:53
# 14   502540300  7/12/2014 07:43:36  1321255088  7/12/2014 07:41:41
# 15   502540301  7/12/2014 00:10:09  1321084151  7/12/2014 00:09:51
# 16   502540301  7/12/2014 00:10:43  1321084484  7/12/2014 00:10:31
# 17   502540301  7/12/2014 00:42:20  1321101178  7/12/2014 00:41:49
# 18   502540301  7/12/2014 00:51:15  1321104588  7/12/2014 00:50:10
# 19   502540301  7/12/2014 01:01:13  1321108537  7/12/2014 01:00:49
# 20   502540301  7/12/2014 01:21:36  1321116696  7/12/2014 01:20:54
# 21   502540301  7/12/2014 01:53:16  1321128115  7/12/2014 01:52:10
# 22   502540301  7/12/2014 01:58:41  1321130273  7/12/2014 01:57:59
# 23   502540301  7/12/2014 03:32:34  1321166082  7/12/2014 03:31:48
# 24   502540301  7/12/2014 03:36:33  1321167778  7/12/2014 03:36:21
# 8             prodege    17334212      CAN      NB       Fredericton
# 9              neodev    15825691      CAN      BC            Surrey
# 10   paiddailysurveys    11786001      USA      NC            Waxhaw
# 11          clixsense    25595227      CAN      SK  North Battleford
# 12          clixsense     6355877      GBR      I7         Newcastle
# 13        tremorgames    28013393      USA      CA    Rancho Cordova
# 14             neodev    21515166      NLD      11          Nootdorp
# 15             neodev    15848372      AUS       2           Jannali
# 16            instagc    25990856      USA      NV         Las Vegas
# 17            instagc    13763729      USA     NaN               NaN
# 18              elite    28276268      USA      CA         San Diego
# 19          clixsense     8888883      USA      FL           Orlando
# 20            instagc    23149109      USA      NC            Durham
# 21        rewardsspot    24482174      GBR      H9            London
# 22            instagc    18531561      CAN      ON       Mississauga
# 23          clixsense     6365250      CAN      BC           Burnaby
# 24          zoombucks     5919735      USA      PA          Lansdale
# 25            instagc    19686223      CAN      BC            Surrey
# 26   paiddailysurveys    11786001      USA      NC            Waxhaw
# 27          clixsense    25595227      CAN      SK  North Battleford
# 28             neodev    18755947      GBR      H2        Accrington
# 29             neodev    21515166      NLD      11          Nootdorp
# ..                ...         ...      ...     ...               ...
# 720            neodev    25224036      CAN      ON           Sudbury
# 721         clixsense    19803139      NLD      11            Leiden
# 722           instagc    13763729      USA     NaN               NaN
# 723             elite    28276268      USA      CA         San Diego
# 724       rewardsspot    24482174      GBR      H9            London
# 725         zoombucks     5919735      USA      PA          Lansdale
# 726           instagc    19686223      CAN      BC            Surrey
# 727       tremorgames    28013393      USA      CA    Rancho Cordova
# 728            neodev    11051762      NLD       9           Utrecht
# 729            neodev    18755947      GBR      H2        Accrington
# 730            neodev    17610000      GBR      I2        Manchester
# 731         clixsense    19162475      GBR      M3             Frome
# 732           instagc    28301350      GBR      K4          Plymouth
# 733           prodege    21891314      AUS       7         Glen Iris
# 734           vivatic    25451531      GBR     NaN               NaN
# 735            neodev    25224036      CAN      ON           Sudbury
# 736            neodev    15848372      AUS       2           Jannali
# 737         clixsense    19803139      NLD      11            Leiden
# 738         clixsense    27871219      NLD       7         Amsterdam
# 739         clixsense     8888883      USA      FL           Orlando
# 740             elite    28276268      USA      CA         San Diego
# 741           prodege     7664351      USA      NY            Cicero
# 742            neodev    15825691      CAN      BC            Surrey
# 743           instagc    18531561      CAN      ON       Mississauga
# 744           instagc    19686223      CAN      BC            Surrey
# 745  paiddailysurveys    11786001      USA      NC            Waxhaw
# 746       tremorgames    28013393      USA      CA    Rancho Cordova
# 747            neodev    21515166      NLD      11          Nootdorp
# 748            neodev    18755947      GBR      H2        Accrington
# 749            neodev    11051762      NLD       9           Utrecht
#
#                 _ip                 ...                   b2   e1  e2  expdec  \
# 0      27.96.208.89                 ...                    3  124  38      -1
# 1      68.108.98.78                 ...                    3  124  38      -1
# 2    67.204.218.187                 ...                    3  124  38      -1
# 3     75.182.89.225                 ...                    3  124  38      -1
# 4     76.26.232.146                 ...                    3  124  38      -1
# 5    75.189.206.205                 ...                    3  124  38      -1
# 6       74.111.0.21                 ...                    3  124  38      -1
# 7      46.23.68.180                 ...                    3  124  38      -1
# 8     142.162.42.73                 ...                    3  124  38      -1
# 10   RO-has_definitional_manifestation  904916-FS1
# 11   RO-has_definitional_manifestation  904916-FS1
# 12   RO-has_definitional_manifestation  904916-FS1
# 13   RO-has_definitional_manifestation  904916-FS1
# 14   RO-has_definitional_manifestation  904916-FS1
# 15                        RO-may_treat  907795-FS1
# 16                        RO-may_treat  907795-FS1
# 17                        RO-may_treat  907795-FS1
# 18                        RO-may_treat  907795-FS1
# 19                        RO-may_treat  907795-FS1
# 20                        RO-may_treat  907795-FS1
# 21                        RO-may_treat  907795-FS1
# 22                        RO-may_treat  907795-FS1
# 23                        RO-may_treat  907795-FS1
# 24                        RO-may_treat  907795-FS1
# 25                        RO-may_treat  907795-FS1
# 26                        RO-may_treat  907795-FS1
# 27                        RO-may_treat  907795-FS1
# 28                        RO-may_treat  907795-FS1
# 29                        RO-may_treat  907795-FS1
# ..                                 ...         ...
# 720             RO-has_causative_agent  903986-FS1
# 721             RO-has_causative_agent  903986-FS1
# 722             RO-has_causative_agent  903986-FS1
# 723             RO-has_causative_agent  903986-FS1
# 724             RO-has_causative_agent  903986-FS1
# 725             RO-has_causative_agent  903986-FS1
# 726             RO-has_causative_agent  903986-FS1
# 727             RO-has_causative_agent  903986-FS1
# 728             RO-has_causative_agent  903986-FS1
# 729             RO-has_causative_agent  903986-FS1
# 730             RO-has_causative_agent  903986-FS1
# 731             RO-has_causative_agent  903986-FS1
# 732             RO-has_causative_agent  903986-FS1
# 733             RO-has_causative_agent  903986-FS1
# 734             RO-has_causative_agent  903986-FS1
# 735             RO-has_causative_agent  903744-FS1
# 736             RO-has_causative_agent  903744-FS1
# 737             RO-has_causative_agent  903744-FS1
# 738             RO-has_causative_agent  903744-FS1
# 739             RO-has_causative_agent  903744-FS1
# 740             RO-has_causative_agent  903744-FS1
# 741             RO-has_causative_agent  903744-FS1
# 742             RO-has_causative_agent  903744-FS1
# 743             RO-has_causative_agent  903744-FS1
# 744             RO-has_causative_agent  903744-FS1
# 745             RO-has_causative_agent  903744-FS1
# 746             RO-has_causative_agent  903744-FS1
# 747             RO-has_causative_agent  903744-FS1
# 748             RO-has_causative_agent  903744-FS1
# 749             RO-has_causative_agent  903744-FS1
#
#                                               sentence  \
# 0    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 1    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 2    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 3    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 4    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 5    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 6    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 7    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 8    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 9    OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 10   OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 11   OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 12   OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 13   OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 14   OC RELATED BLOOD PRESSURE/HYPERTENSION is defi...
# 15   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 16   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 17   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 18   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 19   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 20   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 21   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 22   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 23   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 24   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 25   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 26   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 27   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 28   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# 29   Treatment of REFRACTORY DIARRHOEA in AIDS with...
# ..                                                 ...
# 720  LEPROSY (hanseniasis) is caused by chronic inf...
# 721  LEPROSY (hanseniasis) is caused by chronic inf...
# 722  LEPROSY (hanseniasis) is caused by chronic inf...
# 723  LEPROSY (hanseniasis) is caused by chronic inf...
# 724  LEPROSY (hanseniasis) is caused by chronic inf...
# 725  LEPROSY (hanseniasis) is caused by chronic inf...
# 726  LEPROSY (hanseniasis) is caused by chronic inf...
# 727  LEPROSY (hanseniasis) is caused by chronic inf...
# 728  LEPROSY (hanseniasis) is caused by chronic inf...
# 729  LEPROSY (hanseniasis) is caused by chronic inf...
# 730  LEPROSY (hanseniasis) is caused by chronic inf...
# 731  LEPROSY (hanseniasis) is caused by chronic inf...
# 732  LEPROSY (hanseniasis) is caused by chronic inf...
# 733  LEPROSY (hanseniasis) is caused by chronic inf...
# 734  LEPROSY (hanseniasis) is caused by chronic inf...
# 735  YERSINIA PESTIS the causative agent of PLAGUE ...
# 736  YERSINIA PESTIS the causative agent of PLAGUE ...
# 737  YERSINIA PESTIS the causative agent of PLAGUE ...
# 738  YERSINIA PESTIS the causative agent of PLAGUE ...
# 739  YERSINIA PESTIS the causative agent of PLAGUE ...
# 740  YERSINIA PESTIS the causative agent of PLAGUE ...
# 741  YERSINIA PESTIS the causative agent of PLAGUE ...
# 742  YERSINIA PESTIS the causative agent of PLAGUE ...
# 743  YERSINIA PESTIS the causative agent of PLAGUE ...
# 744  YERSINIA PESTIS the causative agent of PLAGUE ...
# 745  YERSINIA PESTIS the causative agent of PLAGUE ...
# 746  YERSINIA PESTIS the causative agent of PLAGUE ...
# 747  YERSINIA PESTIS the causative agent of PLAGUE ...
# 748  YERSINIA PESTIS the causative agent of PLAGUE ...
# 749  YERSINIA PESTIS the causative agent of PLAGUE ...
#
#                        term1                                term2  \
# 0    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 1    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 2    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 3    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 4    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 5    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 6    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 7    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 8    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 9    ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 10   ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 11   ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 12   ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 13   ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 14   ELEVATED BLOOD PRESSURE  RELATED BLOOD PRESSURE/HYPERTENSION
# 15      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 16      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 17      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 18      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 19      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 20      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 21      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 22      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 23      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 24      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 25      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 26      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 27      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 28      REFRACTORY DIARRHOEA                           OCTREOTIDE
# 29      REFRACTORY DIARRHOEA                           OCTREOTIDE
# ..                       ...                                  ...
# 720     MYCOBACTERIUM LEPRAE                              LEPROSY
# 721     MYCOBACTERIUM LEPRAE                              LEPROSY
# 722     MYCOBACTERIUM LEPRAE                              LEPROSY
# 723     MYCOBACTERIUM LEPRAE                              LEPROSY
# 724     MYCOBACTERIUM LEPRAE                              LEPROSY
# 725     MYCOBACTERIUM LEPRAE                              LEPROSY
# 726     MYCOBACTERIUM LEPRAE                              LEPROSY
# 727     MYCOBACTERIUM LEPRAE                              LEPROSY
# 728     MYCOBACTERIUM LEPRAE                              LEPROSY
# 729     MYCOBACTERIUM LEPRAE                              LEPROSY
# 730     MYCOBACTERIUM LEPRAE                              LEPROSY
# 731     MYCOBACTERIUM LEPRAE                              LEPROSY
# 732     MYCOBACTERIUM LEPRAE                              LEPROSY
# 733     MYCOBACTERIUM LEPRAE                              LEPROSY
# 734     MYCOBACTERIUM LEPRAE                              LEPROSY
# 735          YERSINIA PESTIS                               PLAGUE
# 736          YERSINIA PESTIS                               PLAGUE
# 737          YERSINIA PESTIS                               PLAGUE
# 738          YERSINIA PESTIS                               PLAGUE
# 739          YERSINIA PESTIS                               PLAGUE
# 740          YERSINIA PESTIS                               PLAGUE
# 741          YERSINIA PESTIS                               PLAGUE
# 742          YERSINIA PESTIS                               PLAGUE
# 743          YERSINIA PESTIS                               PLAGUE
# 744          YERSINIA PESTIS                               PLAGUE
# 745          YERSINIA PESTIS                               PLAGUE
# 746          YERSINIA PESTIS                               PLAGUE
# 747          YERSINIA PESTIS                               PLAGUE
# 748          YERSINIA PESTIS                               PLAGUE
# 749          YERSINIA PESTIS                               PLAGUE
#
#                                relations
# 0                      [ASSOCIATED_WITH]
# 1                                 [IS_A]
# 2                              [PART_OF]
# 3                                 [IS_A]
# 4                              [SYMPTOM]
# 5                                 [IS_A]
# 6                      [CONTRAINDICATES]
# 7                      [ASSOCIATED_WITH]
# 8                                [OTHER]
# 9                                [OTHER]
# 10                              [CAUSES]
# 11                               [OTHER]
# 12                                [IS_A]
# 13                     [ASSOCIATED_WITH]
# 14                             [SYMPTOM]
# 15                              [TREATS]
# 16                              [TREATS]
# 17                               [OTHER]
# 18                     [ASSOCIATED_WITH]
# 19                              [TREATS]
# 20   [TREATS] [DIAGNOSE_BY_TEST_OR_DRUG]
# 21                              [TREATS]
# 22                              [TREATS]
# 23                              [TREATS]
# 24                              [TREATS]
# 25                              [TREATS]
# 26                             [SYMPTOM]
# 27                              [TREATS]
# 28                              [TREATS]
# 29                              [TREATS]
# ..                                   ...
# 720                            [PART_OF]
# 721                             [CAUSES]
# 722                             [CAUSES]
# 723                             [CAUSES]
# 724                             [CAUSES]
# 725                             [CAUSES]
# 726                             [CAUSES]
# 727                    [ASSOCIATED_WITH]
# 728                             [CAUSES]
# 729                             [CAUSES]
# 730                             [CAUSES]
# 731          [ASSOCIATED_WITH] [SYMPTOM]
# 732                             [CAUSES]
# 733                             [CAUSES]
# 734                             [CAUSES]
# 735                            [PART_OF]
# 736                             [CAUSES]
# 737                             [CAUSES]
# 738                             [CAUSES]
# 739                             [CAUSES]
# 740                             [CAUSES]
# 741                      [MANIFESTATION]
# 742                             [CAUSES]
# 743                             [CAUSES]
# 744                             [CAUSES]
# 745                             [CAUSES]
# 746                             [CAUSES]
# 747                             [CAUSES]
# 748                             [CAUSES]
# 749                             [CAUSES]
#
# [750 rows x 24 columns]

# %% [markdown]
# Creating a class that inherits from `Configuration` lets us define how the input file will be processed:
#
# * `inputColumns`: list of input columns from the .csv file, the input that the workers were shown
# * `outputColumns`: list of output columns with the answers from the workers
# * `processJudgments`: function that defines how the worker judgments wil be processed; default separator for judgments is ','
#
# To build the annotation vector, we also need to specify whether this is an **open-ended** or **closed** task, using the `open_ended_task` variable.
#
# * **open-ended task** means that the annotation space is not known, and workers can freely provide all the choices that apply (e.g. in sound tagging, the workers are provided with a text box to enter all tags they can think of)
# * **closed task** means that the annotations that can occur in the data are already known, and the workers are asked to validate their existence (e.g. for medical relation extraction, the workers pick from a pre-defined multiple-choice set of relations)
#
# If the task we are processing is **closed**, then we also need to provide the list of possible annotations in the `annotation_vector` variable.

# %%
import sys
sys.path.append('../')

from defaultconfig import Configuration

class MedicalRelexConfig(Configuration):
    inputColumns = ["term1", "b1", "e1", "term2", "b2", "e2", "sentence"]
    outputColumns = ["relations"]
    
    # processing of a closed task
    open_ended_task = False
    annotation_vector = [
        "causes", "manifestation", "treats", "prevents", "symptom", "diagnose_by_test_or_drug", "location",
        "side_effect", "contraindicates", "associated_with", "is_a", "part_of", "other", "none"
    ]
    
    def processJudgments(self, judgments):
        # change default separator to whitespace to make it work with our file
        for col in self.outputColumns:
            judgments[col] = judgments[col].apply(lambda x: x.replace(' ',','))
        return judgments

config = MedicalRelexConfig()

# %%
# pre-process the data and create the annotation vectors
from controllers.inputController import processFile
pre_processed_results = processFile(
    root=".", directory="", filename=medical_relex_filename,
    config=config
)

# %%
# run the metrics
from models import Metrics
processed_results = Metrics.run(pre_processed_results, config)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(processed_results["units"]["uqs"])
plt.xlabel("UQS")
plt.ylabel("Units")

# %%
plt.hist(processed_results["units"]["uqs_initial"])
plt.xlabel("UQS")
plt.ylabel("Units")

# %%
plt.hist(processed_results["workers"]["wqs"])
plt.xlabel("WQS")
plt.ylabel("Workers")

# %%
plt.hist(processed_results["workers"]["wqs_initial"])
plt.xlabel("WQS Initial")
plt.ylabel("Workers")

# %%
plt.hist(processed_results["annotations"]["aqs"])
plt.xlabel("AQS")
plt.ylabel("Annotations")

# %%
processed_results["units"]["unit_annotation_score"]
# Out:
# unit
# 502540300    {u'part_of': 5.40643251916e-05, u'treats': 0.0...
# 502540301    {u'part_of': 0.0, u'treats': 0.865439960974, u...
# 502540302    {u'part_of': 5.186181615e-05, u'treats': 0.0, ...
# 502540303    {u'part_of': 0.0, u'treats': 0.987171884374, u...
# 502540304    {u'none': 0.0934607033627, u'treats': 0.0, u'p...
# 502540305    {u'part_of': 4.7896768261e-05, u'treats': 0.0,...
# 502540306    {u'part_of': 0.0696033804089, u'treats': 0.702...
# 502540307    {u'part_of': 0.0710088579434, u'treats': 0.0, ...
# 502540308    {u'part_of': 0.0, u'treats': 0.0824110861103, ...
# 502540309    {u'part_of': 0.0282540103466, u'treats': 0.0, ...
# 502540310    {u'part_of': 0.0, u'treats': 0.717555795362, u...
# 502540311    {u'part_of': 0.0, u'treats': 0.333756648486, u...
# 502540312    {u'part_of': 4.31746872813e-05, u'treats': 0.6...
# 502540313    {u'part_of': 0.0785684579249, u'treats': 0.0, ...
# 502540314    {u'part_of': 0.0, u'treats': 0.930418788752, u...
# 502540315    {u'part_of': 0.0, u'symptom': 0.335044567568, ...
# 502540316    {u'part_of': 0.0, u'treats': 0.394018718567, u...
# 502540317    {u'part_of': 4.35699426877e-05, u'treats': 0.9...
# 502540318    {u'part_of': 4.66898819418e-05, u'treats': 0.6...
# 502540319    {u'part_of': 4.39618084427e-05, u'treats': 0.0...
# 502540320    {u'part_of': 0.125279894395, u'treats': 0.0, u...
# 502540321    {u'diagnose_by_test_or_drug': 0.0800551581035,...
# 502540322    {u'part_of': 0.25130117103, u'treats': 0.0, u'...
# 502540323    {u'part_of': 4.4768045859e-05, u'treats': 0.52...
# 502540324    {u'part_of': 0.0258970696174, u'treats': 0.0, ...
# 502540325    {u'part_of': 0.0, u'treats': 0.900418426716, u...
# 502540326    {u'part_of': 0.0, u'treats': 0.968332893436, u...
# 502540327    {u'diagnose_by_test_or_drug': 0.244154730418, ...
# 502540328    {u'part_of': 4.64145566152e-05, u'treats': 0.9...
# 502540329    {u'part_of': 0.0, u'symptom': 0.16093260257, u...
# 502540330    {u'part_of': 0.0, u'treats': 0.90059506026, u'...
# 502540331    {u'part_of': 0.128361192067, u'treats': 0.1432...
# 502540332    {u'diagnose_by_test_or_drug': 0.0924963936427,...
# 502540333    {u'part_of': 0.0252616454407, u'treats': 0.219...
# 502540334    {u'part_of': 0.257345617999, u'treats': 0.0, u...
# 502540335    {u'part_of': 0.226099136998, u'treats': 0.0, u...
# 502540336    {u'part_of': 4.83640648526e-05, u'symptom': 0....
# 502540337    {u'part_of': 0.0, u'treats': 0.939292276294, u...
# 502540338    {u'part_of': 4.74566734736e-05, u'treats': 0.7...
# 502540339    {u'part_of': 0.0, u'treats': 0.0, u'prevents':...
# 502540340    {u'part_of': 4.92309247304e-05, u'treats': 0.1...
# 502540341    {u'part_of': 0.100261471726, u'treats': 0.0763...
# 502540342    {u'part_of': 4.49077908512e-05, u'treats': 0.0...
# 502540343    {u'part_of': 4.55318925925e-05, u'treats': 0.7...
# 502540344    {u'part_of': 5.18586280028e-05, u'treats': 0.0...
# 502540345    {u'part_of': 0.0, u'symptom': 0.365166561815, ...
# 502540346    {u'part_of': 0.0, u'treats': 0.0, u'prevents':...
# 502540347    {u'part_of': 4.42007303683e-05, u'treats': 0.8...
# 502540348    {u'part_of': 5.07944868965e-05, u'treats': 0.0...
# 502540349    {u'part_of': 4.87725214847e-05, u'treats': 0.0...
# Name: unit_annotation_score, dtype: object

# %%
processed_results["units"]["unit_annotation_score_initial"][502540314]
# Out:
# Counter({'associated_with': 0.06666666666666667,
#          'causes': 0.0,
#          'contraindicates': 0.0,
#          'diagnose_by_test_or_drug': 0.0,
#          'is_a': 0.0,
#          'location': 0.0,
#          'manifestation': 0.0,
#          'none': 0.06666666666666667,
#          'other': 0.13333333333333333,
#          'part_of': 0.0,
#          'prevents': 0.0,
#          'side_effect': 0.0,
#          'symptom': 0.0,
#          'treats': 0.7333333333333333})

# %%
processed_results["units"]["unit_annotation_score"][502540314]
# Out:
# Counter({'associated_with': 0.029379861669453472,
#          'causes': 0.0,
#          'contraindicates': 0.0,
#          'diagnose_by_test_or_drug': 0.0,
#          'is_a': 0.0,
#          'location': 0.0,
#          'manifestation': 0.0,
#          'none': 0.026198699350336814,
#          'other': 0.014002650227893685,
#          'part_of': 0.0,
#          'prevents': 0.0,
#          'side_effect': 0.0,
#          'symptom': 0.0,
#          'treats': 0.9304187887523162})

# %%
processed_results["units"]
# Out:
#             duration  input.b1  input.b2  input.e1  input.e2  \
# unit
# 502540300  61.133333       101         3       124        38
# 502540301  37.466667        13        62        33        72
# 502540302  44.066667        36        36        57        46
# 502540303  49.466667       145       115       157       123
# 502540304  57.866667       278        42       285        48
# 502540305  55.066667        66        10        77        41
# 502540306  54.000000       233       203       244       211
# 502540307  39.533333        43         0        48        17
# 502540308  46.933333        27        72        43        97
# 502540309  42.133333        87       114        95       132
# 502540310  45.133333       125        78       138        87
# 502540311  57.666667       136       162       151       172
# 502540312  57.666667        88       125       108       135
# 502540313  45.333333        85        53        94        79
# 502540314  58.066667       550       510       576       530
# 502540315  59.200000        20       103        26       117
# 502540316  55.000000       147        64       183        99
# 502540317  57.333333        41       128        69       142
# 502540335  Using standardised computer assisted face to f...
# 502540336  A 61 yr old woman with gallbladder stones, dia...
# 502540337  Patients with otitis media received approximat...
# 502540338  With successful treatment of the patient's dep...
# 502540339  ENDOTOXEMIA was evoked by bolus injection of E...
# 502540340  SALMETEROL prevented EXERCISE INDUCED ASTHMA i...
# 502540341  Therefore, although serum P III P can be a use...
# 502540342  When the menstrual cycle is altered, FERTILITY...
# 502540343  Diclofenac sodium was found to be as effective...
# 502540344  The trends in tuberculin reactions of Mantoux ...
# 502540345  A chest x ray showing a large tumor like opaci...
# 502540346  Although effective treatment can prevent seizu...
# 502540347  Natalizumab plus INTERFERON BETA 1A for relaps...
# 502540348  LEPROSY (hanseniasis) is caused by chronic inf...
# 502540349  YERSINIA PESTIS the causative agent of PLAGUE ...
#
#                                     input.term1  \
# unit
# 502540300               ELEVATED BLOOD PRESSURE
# 502540301                  REFRACTORY DIARRHOEA
# 502540302                 RIBOFLAVIN DEFICIENCY
# 502540303                          HYPERTENSION
# 502540304                               THYROID
# 502540305                           WEIGHT LOSS
# 502540306                           BRADYCARDIA
# 502540307                                 FUNGI
# 502540308                      BEESTING ALLERGY
# 502540309                              SEIZURES
# 502540310                         SCHIZOPHRENIA
# 502540311                       OPIOID OVERDOSE
# 502540312                  RHEUMATOID ARTHRITIS
# 502540313                             SYNOPHRYS
# 502540314            OSTEOARTHRITIS OF THE KNEE
# 502540315                                JOINTS
# 502540316  CHRONIC HEPATITIS B VIRUS INFECTIONS
# 502540317          URETHRAL OR RECTAL GONORRHEA
# 502540318                          HYPERTENSION
# 502540319                     MYASTHENIA GRAVIS
# 502540320        ISOLATED PAPULE ON THE FOREARM
# 502540321                               ALLERGY
# 502540322              STREPTOCOCCUS AGALACTIAE
# 502540323                          HYPERTHERMIA
# 502540324        A SOLID MASS OF LEUKEMIA CELLS
# 502540325                  RHEUMATOID ARTHRITIS
# 502540326                             HIRSUTISM
# 502540327                          OSTEOSARCOMA
# 502540328                   PARKINSON'S DISEASE
# 502540329             SPONTANEOUSLY ELEVATED BP
# 502540330   SYMPTOMATIC URINARY TRACT INFECTION
# 502540331                          HYPERTENSION
# 502540332                       POLYPOID MASSES
# 502540333                     PRINZMETAL ANGINA
# 502540334                              BACTERIA
# 502540335                     ATOPIC DERMATITIS
# 502540336                              DIARRHEA
# 502540337                           PHARYNGITIS
# 502540338                            DEPRESSION
# 502540339            ESCHERICHIA COLI ENDOTOXIN
# 502540340               EXERCISE INDUCED ASTHMA
# 502540341                                 LIVER
# 502540342                             FERTILITY
# 502540343            POSTOPERATIVE INFLAMMATION
# 502540344                          TUBERCULOSIS
# 502540345                            HEMOPTYSIS
# 502540346                              SEIZURES
# 502540347                    MULTIPLE SCLEROSIS
# 502540348                  MYCOBACTERIUM LEPRAE
# 502540349                       YERSINIA PESTIS
#
#                                                 input.term2            job  \
# unit
# 502540300               RELATED BLOOD PRESSURE/HYPERTENSION  relex_example
# 502540301                                        OCTREOTIDE  relex_example
# 502540302                                        RIBOFLAVIN  relex_example
# 502540303                                          ATENOLOL  relex_example
# 502540304                                            GOITER  relex_example
# 502540305                   LYMPHOMA PATIENTS WITHOUT IPSID  relex_example
# 502540306                                          ATROPINE  relex_example
# 502540307                                 FUNGAL INFECTIONS  relex_example
# 502540308                         HYPERSENSITIVITY REACTION  relex_example
# 502540309                                STATUS EPILEPTICUS  relex_example
# 502540310                                         CLOZAPINE  relex_example
# 502540311                                        FLUMAZENIL  relex_example
# 502540312                                        ADALIMUMAB  relex_example
# 502540313                        CORNELIA DE LANGE SYNDROME  relex_example
# 502540314                              GLUCOSAMINE SULPHATE  relex_example
# 502540315                                    OSTEOARTHRITIS  relex_example
# 502540316               CHRONIC HEPATITIS C VIRUS INFECTION  relex_example
# 502540317                                    IM CEFTRIAXONE  relex_example
# 502540318                                  PHEOCHROMOCYTOMA  relex_example
# 502540319                  INTRAVENOUS EDROPHONIUM CHLORIDE  relex_example
# 502540320                    PIGMENTED SEBORRHEIC KERATOSIS  relex_example
# 502540321                                       NON ALLERGY  relex_example
# 502540322                  GROUP B STREPTOCOCCAL INFECTIONS  relex_example
# 502540323                          HEPATOCELLULAR CARCINOMA  relex_example
# 502540324                  GRANULO CYTIC OR MYELOID SARCOMA  relex_example
# 502540325                                      AZATHIOPRINE  relex_example
# 502540326                                         FLUTAMIDE  relex_example
# 502540327                                    RETINOBLASTOMA  relex_example
# 502540328                                            L DOPA  relex_example
# 502540329                                      HYPERTENSION  relex_example
# 502540330                             METHENAMINE HIPPURATE  relex_example
# 502540331                                  PHEOCHROMOCYTOMA  relex_example
# 502540332                                ADENOMATOUS POLYPS  relex_example
# 502540333                                        ERGONOVINE  relex_example
# 502540334                                       BACTERIURIA  relex_example
# 502540335                                   ATOPIC DISEASES  relex_example
# 502540336  IMMUNOHISTOCHEMICAL DIAGNOSIS OF SOMATOSTATINOMA  relex_example
# 502540337                                          CEFACLOR  relex_example
# 502540338                                        IMIPRAMINE  relex_example
# 502540339                                       ENDOTOXEMIA  relex_example
# 502540340                                        SALMETEROL  relex_example
# 502540341                          HEPATOCELLULAR CARCINOMA  relex_example
# 502540342                           ENDOMETRIAL HYPERPLASIA  relex_example
# 502540343                              PREDNISOLONE ACETATE  relex_example
# 502540344                            TUBERCULIN SENSITIVITY  relex_example
# 502540345                               BRONCHIAL CARCINOMA  relex_example
# 502540346                                          EPILEPSY  relex_example
# 502540347                                INTERFERON BETA 1A  relex_example
# 502540348                                           LEPROSY  relex_example
# 502540349                                            PLAGUE  relex_example
#
#            metrics.avg_annotations  metrics.avg_cos_clarity  \
# unit
# 502540300                     15.0                 0.624695
# 502540301                     16.0                 0.986394
# 502540302                     16.0                 0.632456
# 502540303                     17.0                 0.977140
# 502540304                     16.0                 0.685994
# 502540305                     16.0                 0.861640
# 502540306                     16.0                 0.905822
# 502540307                     16.0                 0.985527
# 502540308                     18.0                 0.762001
# 502540309                     15.0                 0.745356
# 502540310                     16.0                 0.918559
# 502540311                     17.0                 0.755929
# 502540312                     16.0                 0.894427
# 502540313                     16.0                 0.589768
# 502540314                     15.0                 0.976092
# 502540315                     16.0                 0.668153
# 502540316                     15.0                 0.640184
# 502540317                     15.0                 0.989743
# 502540318                     16.0                 0.894427
# 502540319                     15.0                 0.994135
# 502540320                     17.0                 0.596285
# 502540321                     16.0                 0.547723
# 502540322                     17.0                 0.583460
# 502540323                     15.0                 0.809040
# 502540324                     15.0                 0.911685
# 502540325                     16.0                 0.953463
# 502540326                     15.0                 0.989743
# 502540327                     16.0                 0.462910
# 502540328                     18.0                 0.973329
# 502540329                     15.0                 0.493197
# 502540330                     19.0                 0.963863
# 502540331                     16.0                 0.787839
# 502540332                     15.0                 0.966736
# 502540333                     15.0                 0.900070
# 502540334                     16.0                 0.816497
# 502540335                     15.0                 0.529813
# 502540336                     17.0                 0.744208
# 502540337                     17.0                 0.976546
# 502540338                     17.0                 0.913812
# 502540339                     16.0                 0.944911
# 502540340                     15.0                 0.966736
# 502540341                     16.0                 0.377964
# 502540342                     17.0                 0.700140
# 502540343                     17.0                 0.878114
# 502540344                     16.0                 0.848528
# 502540345                     18.0                 0.668153
# 502540346                     16.0                 0.782624
# 502540347                     16.0                 0.962250
# 502540348                     16.0                 0.979796
# 502540349                     15.0                 0.994135
#
#            metrics.avg_unique_annotations  \
# unit
# 502540300                             7.0
# 502540301                             5.0
# 502540302                             9.0
# 502540303                             3.0
# 502540304                            10.0
# 502540305                             7.0
# 502540306                             6.0
# 502540307                             3.0
# 502540308                             9.0
# 502540309                             6.0
# 502540310                             5.0
# 502540311                             7.0
# 502540312                             6.0
# 502540313                             6.0
# 502540314                             4.0
# 502540315                             6.0
# 502540316                             5.0
# 502540317                             4.0
# 502540318                             6.0
# 502540319                             3.0
# 502540320                             8.0
# 502540321                            10.0
# 502540322                             8.0
# 502540323                             6.0
# 502540324                             5.0
# 502540325                             5.0
# 502540326                             4.0
# 502540327                             7.0
# 502540328                             6.0
# 502540329                             7.0
# 502540330                             6.0
# 502540331                             6.0
# 502540332                             5.0
# 502540333                             5.0
# 502540334                             8.0
# 502540335                             4.0
# 502540336                             7.0
# 502540337                             5.0
# 502540338                             6.0
# 502540339                             5.0
# 502540340                             5.0
# 502540341                            10.0
# 502540342                             9.0
# 502540343                             6.0
# 502540344                             9.0
# 502540345                             8.0
# 502540346                             5.0
# 502540347                             6.0
# 502540348                             4.0
# 502540349                             3.0
#
#                                             output.relations  \
# unit
# 502540300  {u'part_of': 1, u'treats': 0, u'prevents': 0, ...
# 502540301  {u'part_of': 0, u'treats': 12, u'prevents': 0,...
# 502540302  {u'part_of': 1, u'treats': 0, u'prevents': 1, ...
# 502540303  {u'part_of': 0, u'treats': 13, u'prevents': 0,...
# 502540304  {u'none': 1, u'symptom': 2, u'associated_with'...
# 502540305  {u'part_of': 1, u'treats': 0, u'prevents': 1, ...
# 502540306  {u'part_of': 1, u'treats': 8, u'prevents': 1, ...
# 502540307  {u'part_of': 2, u'treats': 0, u'prevents': 0, ...
# 502540308  {u'part_of': 0, u'treats': 1, u'prevents': 0, ...
# 502540309  {u'diagnose_by_test_or_drug': 0, u'part_of': 2...
# 502540310  {u'part_of': 0, u'treats': 9, u'prevents': 0, ...
# 502540311  {u'part_of': 0, u'none': 6, u'treats': 4, u'pr...
# 502540312  {u'part_of': 1, u'treats': 8, u'prevents': 2, ...
# 502540313  {u'part_of': 2, u'treats': 0, u'prevents': 0, ...
# 502540314  {u'part_of': 0, u'none': 1, u'treats': 11, u'p...
# 502540315  {u'part_of': 0, u'treats': 0, u'prevents': 3, ...
# 502540316  {u'part_of': 0, u'none': 1, u'treats': 5, u'pr...
# 502540317  {u'part_of': 1, u'treats': 12, u'prevents': 0,...
# 502540318  {u'part_of': 1, u'treats': 8, u'prevents': 0, ...
# 502540319  {u'part_of': 1, u'associated_with': 0, u'treat...
# 502540320  {u'diagnose_by_test_or_drug': 0, u'part_of': 3...
# 502540321  {u'part_of': 2, u'treats': 0, u'prevents': 1, ...
# 502540322  {u'part_of': 3, u'treats': 0, u'prevents': 0, ...
# 502540323  {u'diagnose_by_test_or_drug': 0, u'part_of': 1...
# 502540324  {u'part_of': 2, u'treats': 0, u'prevents': 0, ...
# 502540325  {u'part_of': 0, u'treats': 10, u'prevents': 1,...
# 502540326  {u'part_of': 0, u'treats': 12, u'prevents': 0,...
# 502540327  {u'part_of': 3, u'treats': 0, u'prevents': 0, ...
# 502540328  {u'part_of': 1, u'treats': 12, u'prevents': 1,...
# 502540329  {u'part_of': 0, u'treats': 0, u'prevents': 0, ...
# 502540330  {u'part_of': 0, u'treats': 12, u'prevents': 1,...
# 502540331  {u'part_of': 2, u'treats': 2, u'prevents': 2, ...
# 502540332  {u'part_of': 1, u'treats': 0, u'prevents': 0, ...
# 502540333  {u'part_of': 1, u'treats': 3, u'prevents': 1, ...
# 502540334  {u'diagnose_by_test_or_drug': 1, u'part_of': 6...
# 502540335  {u'part_of': 4, u'treats': 0, u'prevents': 0, ...
# 502540336  {u'part_of': 1, u'associated_with': 6, u'locat...
# 502540337  {u'part_of': 0, u'treats': 12, u'prevents': 0,...
# 502540338  {u'part_of': 1, u'treats': 9, u'prevents': 0, ...
# 502540339  {u'part_of': 0, u'none': 1, u'treats': 0, u'pr...
# 502540340  {u'part_of': 1, u'treats': 2, u'prevents': 10,...
# 502540341  {u'part_of': 2, u'symptom': 0, u'treats': 1, u...
# 502540342  {u'part_of': 1, u'treats': 1, u'prevents': 1, ...
# 502540343  {u'part_of': 1, u'treats': 8, u'prevents': 3, ...
# 502540344  {u'part_of': 1, u'treats': 1, u'prevents': 1, ...
# 502540345  {u'part_of': 0, u'treats': 1, u'prevents': 0, ...
# 502540346  {u'part_of': 0, u'treats': 0, u'prevents': 1, ...
# 502540347  {u'part_of': 1, u'treats': 10, u'prevents': 1,...
# 502540348  {u'part_of': 1, u'treats': 0, u'prevents': 0, ...
# 502540349  {u'part_of': 1, u'treats': 0, u'prevents': 0, ...
#
#            output.relations.annotations  output.relations.cos_clarity  \
# unit
# 502540300                            15                      0.624695
# 502540301                            16                      0.986394
# 502540302                            16                      0.632456
# 502540303                            17                      0.977140
# 502540304                            16                      0.685994
# 502540305                            16                      0.861640
# 502540306                            16                      0.905822
# 502540307                            16                      0.985527
# 502540308                            18                      0.762001
# 502540309                            15                      0.745356
# 502540310                            16                      0.918559
# 502540311                            17                      0.755929
# 502540312                            16                      0.894427
# 502540313                            16                      0.589768
# 502540314                            15                      0.976092
# 502540304  {u'none': 0.0934607033627, u'treats': 0.0, u'p...
# 502540305  {u'part_of': 4.7896768261e-05, u'treats': 0.0,...
# 502540306  {u'part_of': 0.0696033804089, u'treats': 0.702...
# 502540307  {u'part_of': 0.0710088579434, u'treats': 0.0, ...
# 502540308  {u'part_of': 0.0, u'treats': 0.0824110861103, ...
# 502540309  {u'part_of': 0.0282540103466, u'treats': 0.0, ...
# 502540310  {u'part_of': 0.0, u'treats': 0.717555795362, u...
# 502540311  {u'part_of': 0.0, u'treats': 0.333756648486, u...
# 502540312  {u'part_of': 4.31746872813e-05, u'treats': 0.6...
# 502540313  {u'part_of': 0.0785684579249, u'treats': 0.0, ...
# 502540314  {u'part_of': 0.0, u'treats': 0.930418788752, u...
# 502540315  {u'part_of': 0.0, u'symptom': 0.335044567568, ...
# 502540316  {u'part_of': 0.0, u'treats': 0.394018718567, u...
# 502540317  {u'part_of': 4.35699426877e-05, u'treats': 0.9...
# 502540318  {u'part_of': 4.66898819418e-05, u'treats': 0.6...
# 502540319  {u'part_of': 4.39618084427e-05, u'treats': 0.0...
# 502540320  {u'part_of': 0.125279894395, u'treats': 0.0, u...
# 502540321  {u'diagnose_by_test_or_drug': 0.0800551581035,...
# 502540322  {u'part_of': 0.25130117103, u'treats': 0.0, u'...
# 502540323  {u'part_of': 4.4768045859e-05, u'treats': 0.52...
# 502540324  {u'part_of': 0.0258970696174, u'treats': 0.0, ...
# 502540325  {u'part_of': 0.0, u'treats': 0.900418426716, u...
# 502540326  {u'part_of': 0.0, u'treats': 0.968332893436, u...
# 502540327  {u'diagnose_by_test_or_drug': 0.244154730418, ...
# 502540328  {u'part_of': 4.64145566152e-05, u'treats': 0.9...
# 502540329  {u'part_of': 0.0, u'symptom': 0.16093260257, u...
# 502540330  {u'part_of': 0.0, u'treats': 0.90059506026, u'...
# 502540331  {u'part_of': 0.128361192067, u'treats': 0.1432...
# 502540332  {u'diagnose_by_test_or_drug': 0.0924963936427,...
# 502540333  {u'part_of': 0.0252616454407, u'treats': 0.219...
# 502540334  {u'part_of': 0.257345617999, u'treats': 0.0, u...
# 502540335  {u'part_of': 0.226099136998, u'treats': 0.0, u...
# 502540336  {u'part_of': 4.83640648526e-05, u'symptom': 0....
# 502540337  {u'part_of': 0.0, u'treats': 0.939292276294, u...
# 502540338  {u'part_of': 4.74566734736e-05, u'treats': 0.7...
# 502540339  {u'part_of': 0.0, u'treats': 0.0, u'prevents':...
# 502540340  {u'part_of': 4.92309247304e-05, u'treats': 0.1...
# 502540341  {u'part_of': 0.100261471726, u'treats': 0.0763...
# 502540342  {u'part_of': 4.49077908512e-05, u'treats': 0.0...
# 502540343  {u'part_of': 4.55318925925e-05, u'treats': 0.7...
# 502540344  {u'part_of': 5.18586280028e-05, u'treats': 0.0...
# 502540345  {u'part_of': 0.0, u'symptom': 0.365166561815, ...
# 502540346  {u'part_of': 0.0, u'treats': 0.0, u'prevents':...
# 502540347  {u'part_of': 4.42007303683e-05, u'treats': 0.8...
# 502540348  {u'part_of': 5.07944868965e-05, u'treats': 0.0...
# 502540349  {u'part_of': 4.87725214847e-05, u'treats': 0.0...
