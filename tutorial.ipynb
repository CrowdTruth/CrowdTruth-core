# %% [markdown]
# # Installing CrowdTruth

# %%
sudo pip install crowdtruth

# %% [markdown]
# # Get input data
# In order to process crowdsourcing data, we need some actual crowdsourcing results. CrowdTruth supports `csv` result files from Crowdflower and Amazon Mechanical Turk. If you put multiple crowdsourcing job files into one folder, then these files are aggregated together. You will be able to see the individual performance of each job in the results.
# You can download example files from https://github.com/CrowdTruth/CrowdTruth-core/tree/master/examples.

# %%
import os
directory = '/Users/benjamin/Google Drive/Crowd-WATSON/Research/Benjamin/Data/controcurator/test/'
os.chdir(directory)

# Open the first CSV to get a preview of the data
import pandas as pd
df = pd.read_csv(directory+[doc for doc in os.listdir(directory) if doc.endswith('.csv')][0])

from IPython.display import display
display(df.head())
# Out:
#      _unit_id         _created_at         _id         _started_at _tainted  \
# 0  1132303217  1/10/2017 15:16:56  2338172846  1/10/2017 15:16:16    False
# 1  1132303217  1/10/2017 17:30:52  2338281290  1/10/2017 17:30:17    False
# 2  1132303217  1/10/2017 17:35:52  2338286399  1/10/2017 17:34:49    False
# 3  1132303217  1/10/2017 18:30:31  2338346519  1/10/2017 18:29:27    False
# 4  1132303217  1/10/2017 19:23:56  2338415947  1/10/2017 19:23:27    False
#
#          _channel  _trust  _worker_id _country _region  \
# 0          neodev  0.9922    18881135      CAN      NB
# 1          neodev  0.6021    12686314      USA      IN
# 2      prizerebel  0.6382    35607359      USA      MI
# 3         instagc  0.5781    22298499      USA      DE
# 4  content_runner  0.5812    41449612      GBR     NaN
#
#                          ...                         persistence_gold  \
# 0                        ...                                      NaN
# ...

# %% [markdown]
# # Running CrowdTruth

# %%
import crowdtruth

print os.getcwd()
#crowdtruth
